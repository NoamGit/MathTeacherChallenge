# %%
import pandas as pd

# %%
train_data = pd.read_json(r'C:\Users\Five\Documents\DataHack\Data\dolphin-number_word_std\number_word_std.dev.json')

# %%
train_data
# Out:
#                                       ans                   ans_simple  \
# 0                                 {40;29}                     [40, 29]
# 1                                    6; 9                       [6, 9]
# 2                                {34; 28}                     [34, 28]
# 3                                 {42;26}                     [42, 26]
# 4                                {77; 20}                     [77, 20]
# 5                                {20; -2}                     [20, -2]
# 6             {45/2; 27/2} | {22.5; 13.5}                 [22.5, 13.5]
# 7                                {20; 16}                     [20, 16]
# 8                                {23; 14}                     [23, 14]
# 9                                  13; 20                     [13, 20]
# 10                               {32; 56}                     [32, 56]
# 11                                {8; 20}                      [8, 20]
# 12                                {9; 14}                      [9, 14]
# 13                             10; 12; 14                 [10, 12, 14]
# 14                          -93; -91; -89              [-93, -91, -89]
# 15                          -41; -39; -37              [-41, -39, -37]
# 16                          -27; -25; -23              [-27, -25, -23]
# 17                         {2.764; 7.236}  [2.7640000000000002, 7.236]
# 18                               {16; 48}                     [16, 48]
# 19                               {18; 73}                     [18, 73]
# 20                                    226                        [226]
# 21                                   4; 7                       [4, 7]
# 22                                7; 8; 9                    [7, 8, 9]
# 23                                      6                          [6]
# 24                                      9                          [9]
# 25                                      2                          [2]
# 26                     11; 12 or -12; -11                     [11, 12]
# 27                                     59                         [59]
# 28                                     26                         [26]
# 29                                     78                         [78]
# ..                                    ...                          ...
# 344                                    64                         [64]
# 345                                     6                          [6]
# 346                            88; 89; 90                 [88, 89, 90]
# 347                                   198                        [198]
# 348                          -3; -1; 1; 3               [-3, -1, 1, 3]
# 349  20/9; 20 or 0; 0 | 2.222; 20 or 0; 0                  [2.222, 20]
# 350                          264/5 | 52.8                       [52.8]
# 351                           2/3 | 0.667                      [0.667]
# 352                                     6                          [6]
# 353                                  -156                       [-156]
# 354                             3; 12; 48                  [3, 12, 48]
# 355                        25 | 25 or -25                         [25]
# 356                                    -5                         [-5]
# 357                                   728                        [728]
# 358                                 2; 77                      [2, 77]
# 359                         6/65 | 0.0923        [0.09230000000000001]
# 360                                  9/16                     [0.5625]
# 361                                  5; 6                       [5, 6]
# 362                               -9 or 8                         [-9]
# 363                                    40                         [40]
# 364                                   765                        [765]
# 365                           9/8 | 1.125                      [1.125]
# 366                                     6                          [6]
# 367                                   567                        [567]
# 368                                  9/14                   [0.642857]
# 369                                  3; 5                       [3, 5]
# 370                         9; 11; 13; 15              [9, 11, 13, 15]
# 371                                     5                          [5]
# 372                                     4                          [4]
# 373                                     8                          [8]
#
#                                              equations  \
# 0             [unkn: x,y, equ: x=y+11, equ: 3*x=4*y+4]
# 1     [unkn: x,y, equ: x + 3 = y, equ: 2*y + 12 = 5*x]
# 2                 [unkn: x,y, equ: x+y=62, equ: x-y=6]
# 3                [unkn: x,y, equ: x+y=68, equ: x-y=16]
# 4                [unkn: x,y, equ: x+y=97, equ: x-y=57]
# 5                [unkn: x,y, equ: x+y=18, equ: x-y=22]
# 6                 [unkn: x,y, equ: x+y=36, equ: x-y=9]
# 7                 [unkn: x,y, equ: x+y=36, equ: y-x=4]
# 8                 [unkn: x,y, equ: x-y=9, equ: x+y=37]
# 9                 [unkn: x,y, equ: x=y-7, equ: x+y=33]
# 10               [unkn: x,y, equ: x-y=24, equ: x+y=88]
# 11       [unkn: m,n, equ: m = n - 12, equ: m + n = 28]
# 12        [unkn: x,y, equ: x + y = 23, equ: x = 5 + y]
# 13   [unkn: 2*k-2,2*k,2*k+2, equ: (2*k-2)+(2*k+2)=3...
# 14   [unkn: 2*k-1,2*k+1,2*k+3, equ: (2*k-1)+(2*k+1)...
# 15   [unkn: 2*k-1,2*k+1,2*k+3, equ: (2*k-1)+(2*k+1)...
# 16   [unkn: 2*k-1,2*k+1,2*k+3, equ: (2*k-1)+(2*k+1)...
# 17      [unkn: x, y, equ: x + y = 10, equ: x * y = 20]
# 18         [unkn: x,y, equ: x+y=64, equ: y - 2*x = 16]
# 19      [unkn: x,y, equ: x + y = 91, equ: x = 1 + 4*y]
# 20                         [unkn: s, equ: s = 3 + 223]
# 21   [unkn: x,y, equ: x+3=y, equ: x^2+y^2=65, equ: ...
# 22        [unkn: x-1,x,x+1, equ: 3*((x-1)+x+(x+1))=72]
# 23                        [unkn: x, equ: 2+6*x=20+3*x]
# 24                  [unkn: n, equ: 15 + 4*n = 6 + 5*n]
# 25                   [unkn: n, equ: 6*n - 5 = 8*n - 9]
# 26                   [unkn: x,x+1, equ: (x+x+1)^2=529]
# 27   [unkn: 10*x+y, equ: (x+y)=14, equ: 36+(10*x+y)...
# 28   [unkn: 10*x+y, equ: x+y=8, equ: 10*x+y+36=10*y+x]
# 29   [unkn: x+10*y, equ: x+y=15, equ: (10*x+y)-(x+1...
# ..                                                 ...
# 344  [unkn: m, equ: m = 10*x + y, equ: x + y = 10, ...
# 345    [unkn: x, equ: 1/2 * (x + 2) = 1/3 * (3*x - 6)]
# 346  [unkn: x, y, z, equ: x + 1 = y, equ: y + 1 = z...
# 347  [unkn: d, equ: m = 100*x + 10*y + z, equ: m + ...
# 348  [unkn: x, y, z, m, equ: x + 2 = y, equ: y + 2 ...
# 349  [unkn: x, y, equ: 2 * (x + y) = x * y, equ: y ...
# 350             [unkn: x, equ: x = (3+2/3) * (14+2/5)]
# 351        [unkn: x, equ: x = (1/3 + 1/2) - 1/3 * 1/2]
# 352                       [unkn: x, equ: 2+x/7 = 20/7]
# 353       [unkn: y, equ: x + 1 = y, equ: x + y = -313]
# 354  [unkn: a,ar,a*r^2, equ: a + ar = 15, equ: ar +...
# 355  [unkn: s, equ: s = n + (n+1), equ: 1 + n(n+1) ...
# 356        [unkn: y-z, equ: x + y = 4, equ: x + z = 9]
# 357                  [unkn: n, equ: n = 9 * 9 * 9 - 1]
# 358  [unkn: d,s, equ: a + (8-1)*d = 3(a + (3-1)*d),...
# 359       [unkn: x, equ: 1/2*x + 1/3*x + 1/4*x = 1/10]
# 360  [unkn: r, equ: (n+3)/d = 3/4, equ: n/(d-7)=1, ...
# 361    [unkn: k,k+1, equ: k^2 < 29, equ: (k+1)^2 > 29]
# 362               [unkn: n, equ: 1/n - 1/(n+1) = 1/72]
# 363                   [unkn: x, equ:  (x+x+1)^(1/2)=9]
# 364  [unkn: s, equ: 3*2^(n-1) = 384, equ: s = 3*(2^...
# 365                   [unkn: x, equ: 2- 1/(4*x) = 2/x]
# 366  [unkn: r, equ: s = (2004+2040)(2040-2004+1)/2,...
# 367  [unkn: n, equ: n = 100*a+10*b+c, equ: 100*c+10...
# 368  [unkn: f, equ: f = n/d, equ: n = d - 5, equ: (...
# 369  [unkn: 2*n+1,2*n+3, equ: 1/(2*n+1) + 1/(2*n+3)...
# 370  [unkn: m, n, x, y, equ: m % 2 = 1, equ: m + 2 ...
# 371                [unkn: n, equ: (17-n)/(25-n) = 3/5]
# 372                [unkn: x, equ: 1/x - 1/(3*x) = 1/6]
# 373                         [unkn: x^32, equ: x^64=64]
#
#                                       id  index  \
# 0                     algebra.com.117395   1043
# 1    yahoo.answers.20091227181039aazhen8   1617
# 2                     algebra.com.101793     49
# 3                     algebra.com.112903   1032
# 4                     algebra.com.193198   1256
# 5                     algebra.com.196398   1261
# 6                     algebra.com.216868   1337
# 7                       algebra.com.3133     40
# 8                     algebra.com.432985    594
# 9                     algebra.com.437200    596
# 10                    algebra.com.612557    736
# 11   yahoo.answers.20070524141453aahh0nv   1404
# 12   yahoo.answers.20091207064212aaklfpn   1859
# 13                    algebra.com.158269    134
# 14                     algebra.com.15515    130
# 15                    algebra.com.228612    225
# 16                    algebra.com.606748    733
# 17   yahoo.answers.20070527111158aax4f93   1682
# 18                    algebra.com.142635   1364
# 19   yahoo.answers.20080911174339aamgdzd   1521
# 20   yahoo.answers.20080518194625aajwvcy   1494
# 21                    algebra.com.289589    357
# 22                    algebra.com.367532    505
# 23                    algebra.com.157265   1160
# 24   yahoo.answers.20080724143616aaciqtd   1510
# 25   yahoo.answers.20100402174544aakgste   1622
# 26                    algebra.com.135912     99
# 27                    algebra.com.172001   1217
# 28                      algebra.com.1775     21
# 29                    algebra.com.259429    295
# ..                                   ...    ...
# 344  yahoo.answers.20070618131738aad5cjo   1685
# 345  yahoo.answers.20070620184612aaogvvs   1686
# 346  yahoo.answers.20080227002318aaijr8r   1721
# 347  yahoo.answers.20080301140524aa5b9ac   1722
# 348  yahoo.answers.20080907131624aaulmig   1760
# 349  yahoo.answers.20080928211132aayel0h   1768
# 350  yahoo.answers.20090107100614aa9aafb   1787
# 351  yahoo.answers.20090128195405aa1itoq   1790
# 352  yahoo.answers.20090519125016aavwxwx   1812
# 353  yahoo.answers.20101010184448aa8u6sn   1827
# 354  yahoo.answers.20071008201230aamkoog   1840
# 355  yahoo.answers.20071117082122aawk9lw   1841
# 356  yahoo.answers.20090802072052aaig730   1856
# 357  yahoo.answers.20100223152723aamnuu0   1860
# 358  yahoo.answers.20080209040552aaqryvi   1864
# 359  yahoo.answers.20090307150215aabkata   1872
# 360                   algebra.com.196334   1260
# 361                   algebra.com.205586   1286
# 362                   algebra.com.445017    603
# 363                   algebra.com.626205    744
# 364  yahoo.answers.20070507182402aamc6f8   1399
# 365  yahoo.answers.20070731081228aae3oxl   1688
# 366  yahoo.answers.20071129002631aacgkpr   1441
# 367  yahoo.answers.20071202194928aa7twrd   1443
# 368  yahoo.answers.20071214233524aamomnu   1845
# 369  yahoo.answers.20080110151408aac8lab   1451
# 370  yahoo.answers.20080223145503aae1l0o   1720
# 371  yahoo.answers.20081015044921aar6q2v   1536
# 372  yahoo.answers.20090326121242aan4cdh   1804
# 373  yahoo.answers.20090330140410aayuqmu   1587
#
#                                                sources  \
# 0                                   algebra.com.117395
# 1    https://answers.yahoo.com/question/index?qid=2...
# 2                                   algebra.com.101793
# 3                                   algebra.com.112903
# 4                                   algebra.com.193198
# 5                                   algebra.com.196398
# 6                                   algebra.com.216868
# 7                                     algebra.com.3133
# 8                                   algebra.com.432985
# 9                                   algebra.com.437200
# 10                                  algebra.com.612557
# 11   https://answers.yahoo.com/question/index?qid=2...
# 12   https://answers.yahoo.com/question/index?qid=2...
# 13                                  algebra.com.158269
# 14                                   algebra.com.15515
# 15                                  algebra.com.228612
# 16                                  algebra.com.606748
# 17   https://answers.yahoo.com/question/index?qid=2...
# 18                                  algebra.com.142635
# 19   https://answers.yahoo.com/question/index?qid=2...
# 20   https://answers.yahoo.com/question/index?qid=2...
# 21                                  algebra.com.289589
# 22                                  algebra.com.367532
# 23                                  algebra.com.157265
# 24   https://answers.yahoo.com/question/index?qid=2...
# 25   https://answers.yahoo.com/question/index?qid=2...
# 26                                  algebra.com.135912
# 27                                  algebra.com.172001
# 28                                    algebra.com.1775
# 29                                  algebra.com.259429
# ..                                                 ...
# 344  https://answers.yahoo.com/question/index?qid=2...
# 345  https://answers.yahoo.com/question/index?qid=2...
# 346  [https://answers.yahoo.com/question/index?qid=...
# 347  https://answers.yahoo.com/question/index?qid=2...
# 348  https://answers.yahoo.com/question/index?qid=2...
# 349  https://answers.yahoo.com/question/index?qid=2...
# 350  https://answers.yahoo.com/question/index?qid=2...
# 351  https://answers.yahoo.com/question/index?qid=2...
# 352  [https://answers.yahoo.com/question/index?qid=...
# 353  https://answers.yahoo.com/question/index?qid=2...
# 354  https://answers.yahoo.com/question/index?qid=2...
# 355  https://answers.yahoo.com/question/index?qid=2...
# 356  https://answers.yahoo.com/question/index?qid=2...
# 357  https://answers.yahoo.com/question/index?qid=2...
# 358  https://answers.yahoo.com/question/index?qid=2...
# 359  https://answers.yahoo.com/question/index?qid=2...
# 360                                 algebra.com.196334
# 361                                 algebra.com.205586
# 362                                 algebra.com.445017
# 363                                 algebra.com.626205
# 364  https://answers.yahoo.com/question/index?qid=2...
# 365  https://answers.yahoo.com/question/index?qid=2...
# 366  https://answers.yahoo.com/question/index?qid=2...
# 367  https://answers.yahoo.com/question/index?qid=2...
# 368  https://answers.yahoo.com/question/index?qid=2...
# 369  https://answers.yahoo.com/question/index?qid=2...
# 370  https://answers.yahoo.com/question/index?qid=2...
# 371  https://answers.yahoo.com/question/index?qid=2...
# 372  https://answers.yahoo.com/question/index?qid=2...
# 373  https://answers.yahoo.com/question/index?qid=2...
#
#                                                   text
# 0    one number is 11 more than another number. Fin...
# 1    One number is 3 less than a second number. Twi...
# 2    Find two numbers whose sum is 62 and whose dif...
# 3    the sum of two numbers is 68. their difference...
# 4    the sum of two numbers is 97. the difference o...
# 5    the sum of two numbers is 18. their difference...
# 6    i have two numbers. the sum is 36 and the diff...
# 7    The sum of 2 integers is 36. The difference of...
# 8    The difference of two numbers is 9 and their s...
# 9    One number is seven less than another number. ...
# 10   The difference between two numbers is 24. Find...
# 11   A number is 12 less than another.  The sum of ...
# 12   The sum of two numbers is twenty-three, and th...
# 13   If the first and third of three consecutive ev...
# 14   The sum of three consecutive odd integers is -...
# 15   the sum of three consecutive odd integers is -...
# 16   what three consecutive odd integers have a sum...
# 17        Find two numbers with sum 10 and product 20.
# 18   The sum of two numbers is 64. If twice the sma...
# 19   The sum of two numbers is 91.  The larger numb...
# 20   What is the sum of the distinct prime factors ...
# 21   One positive integer is 3 less than a second p...
# 22   Three times the sum of three consecutive integ...
# 23   2 more than 6 times a number is 20 more than 3...
# 24   Fifteen more than four times a number is 6 mor...
# 25   5 less than 6 times a whole number is 9 less t...
# 26   The square of the sum of two consecutive integ...
# 27   a no. has two digits whose sum is 14. if 36 is...
# 28   The sum of the digits of a two digit number is...
# 29   the sum of the digits of a two digit number is...
# ..                                                 ...
# 344  The sum of the digits of a 2-digit is 10. If t...
# 345  One half the sum of a number and 2 is equal to...
# 346  Find the 3 consecutive integers with the sum o...
# 347  A three digit number grows by 9 if we exchange...
# 348  Find four consecutive odd integers so that the...
# 349  Find two numbers so that twice their sum equal...
# 350           What is the product of 3+2/3 and 14+2/5?
# 351  When the product of 1/3 and 1/2 is subtracted ...
# 352              What is the number x in 2+x/7 = 20/7?
# 353  The sum of two consecutive integers is -313. F...
# 354  The first and second terms of a geometric sequ...
# 355  if the sum of lcm and gcd of 2 consecutive num...
# 356  If x + y = 4, and x + z = 9, what is the value...
# 357  How many positive integers less than 1,000 do ...
# 358  In an arithmetic progression, the 8th term is ...
# 359  The sum of one half of a number, one third of ...
# 360  If the numerator of a fraction is increased by...
# 361  Which two consecutive whole numbers is square ...
# 362  The difference of the reciprocals of two conse...
# 363  the square root of the sum of two consecutive ...
# 364      Finding the sum of series. 3+6+12+24+...+384?
# 365  When the reciprocal of 4 times a number is sub...
# 366  The number A = 200420052006....2040 is formed ...
# 367  The digits of a three digit number are consecu...
# 368  The numerator of a fraction is 5 less than the...
# 369  The sum of the reciprocals of two consecutive ...
# 370  The sum of 4 consecutive odd integers is 3 mor...
# 371  What number can be subtracted from both the nu...
# 372  When the reciprocal of three times a number is...
# 373                        if x^64 = 64 then x ^32 = ?
#
# [374 rows x 7 columns]
